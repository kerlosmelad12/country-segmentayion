# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Country-data.csv")
data.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
data.shape
# Out:
# (167, 10)

# %%
data.drop_duplicates()
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
data.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %%
data.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
data.columns
# Out:
# Index(['country', 'child_mort', 'exports', 'health', 'imports', 'income',
#        'inflation', 'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
data["country"].value_counts()
# Out:
# country
# Afghanistan    1
# Morocco        1
# Myanmar        1
# Namibia        1
# Nepal          1
#               ..
# Georgia        1
# Germany        1
# Ghana          1
# Greece         1
# Zambia         1
# Name: count, Length: 167, dtype: int64

# %%
data[["country","gdpp"]].value_counts().sort_values(ascending=False)
# Out:
# country              gdpp
# Afghanistan          553      1
# Croatia              13500    1
# Algeria              4460     1
# Angola               3530     1
# Antigua and Barbuda  12200    1
#                              ..
# Vanuatu              2970     1
# Venezuela            13500    1
# Vietnam              1310     1
# Yemen                1310     1
# Zambia               1460     1
# Name: count, Length: 167, dtype: int64

# %%
data.groupby('country').sum().sort_values(['gdpp'],ascending=False).head(10)[['gdpp']]
# Out:
#                  gdpp
# country
# Luxembourg     105000
# Norway          87800
# Switzerland     74600
# Qatar           70300
# Denmark         58000
# Sweden          52100
# Australia       51900
# Netherlands     50300
# Ireland         48700
# United States   48400

# %%
data.groupby('country').sum().sort_values(['life_expec'],ascending=False)[['life_expec']].head(10)
# Out:
#              life_expec
# country
# Japan              82.8
# Singapore          82.7
# Switzerland        82.2
# Iceland            82.0
# Australia          82.0
# Spain              81.9
# Italy              81.7
# Sweden             81.5
# Israel             81.4
# France             81.4

# %%
data.groupby('country').sum().sort_values('income',ascending=False).head(10)[["income"]]
# Out:
#                       income
# country
# Qatar                 125000
# Luxembourg             91700
# Brunei                 80600
# Kuwait                 75200
# Singapore              72100
# Norway                 62300
# United Arab Emirates   57600
# Switzerland            55500
# United States          49400
# Ireland                45700

# %%
plt.figure(figsize=(10,8))
sns.jointplot(data=data,x='income',y='gdpp')
plt.show()

# %%
x=data.groupby('country').sum().sort_values('child_mort',ascending=False)[['child_mort']].head(10)
y=data.groupby('country').sum().sort_values('health',ascending=False)[['health']].head(10)
plt.figure(figsize=(12, 6))  # Set figure size

for idx, df in enumerate([x, y], start=1):
    plt.subplot(1, 2, idx)  # Adjust subplot position dynamically
    df.plot(kind='bar', ax=plt.gca())  # Use the current axis (`plt.gca()`)
    plt.title(df.columns[0])  # Set title based on column name
    plt.ylabel(df.columns[0])  # Set y-axis label
    plt.xlabel('Country')  # Set x-axis label

plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.relplot(data=data,x='life_expec',y='total_fer')
plt.show()

# %%
data.groupby('country').sum().sort_values(["imports","exports"],ascending=False)[['imports','exports']].head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %%
data.groupby('country').sum().sort_values('gdpp',ascending=False).head(10)[["gdpp"]].plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %%
df_drop=data.drop('country',axis=1)
df_drop
# Out:
#      child_mort  exports  health  imports  income  inflation  life_expec  \
# 0          90.2     10.0    7.58     44.9    1610       9.44        56.2
# 1          16.6     28.0    6.55     48.6    9930       4.49        76.3
# 2          27.3     38.4    4.17     31.4   12900      16.10        76.5
# 3         119.0     62.3    2.85     42.9    5900      22.40        60.1
# 4          10.3     45.5    6.03     58.9   19100       1.44        76.8
# ..          ...      ...     ...      ...     ...        ...         ...
# 162        29.2     46.6    5.25     52.7    2950       2.62        63.0
# 163        17.1     28.5    4.91     17.6   16500      45.90        75.4
# 164        23.3     72.0    6.84     80.2    4490      12.10        73.1
# 165        56.3     30.0    5.18     34.4    4480      23.60        67.5
# 166        83.1     37.0    5.89     30.9    3280      14.00        52.0
#
#      total_fer   gdpp
# 0         5.82    553
# 1         1.65   4090
# ...

# %%
from sklearn.preprocessing import StandardScaler
x_std=StandardScaler().fit_transform(df_drop)

# %%
x_std
# Out:
# array([[ 1.29153238, -1.13827979,  0.27908825, ..., -1.61909203,
#          1.90288227, -0.67917961],
#        [-0.5389489 , -0.47965843, -0.09701618, ...,  0.64786643,
#         -0.85997281, -0.48562324],
#        [-0.27283273, -0.09912164, -0.96607302, ...,  0.67042323,
#         -0.0384044 , -0.46537561],
#        ...,
#        [-0.37231541,  1.13030491,  0.0088773 , ...,  0.28695762,
#         -0.66120626, -0.63775406],
#        [ 0.44841668, -0.40647827, -0.59727159, ..., -0.34463279,
#          1.14094382, -0.63775406],
#        [ 1.11495062, -0.15034774, -0.33801514, ..., -2.09278484,
#          1.6246091 , -0.62954556]])

# %%
mean_vec=np.mean(x_std,axis=0)
cov_matraix=(x_std-mean_vec).T.dot((x_std-mean_vec)) / (x_std.shape[0]-1)
cov_matraix
# Out:
# array([[ 1.0060241 , -0.32000945, -0.2016093 , -0.12797725, -0.52747354,
#          0.29001277, -0.89201752,  0.85358942, -0.485942  ],
#        [-0.32000945,  1.0060241 , -0.11509761,  0.74182289,  0.51989676,
#         -0.10794074,  0.3182181 , -0.32193832,  0.42124719],
#        [-0.2016093 , -0.11509761,  1.0060241 ,  0.09629328,  0.1303592 ,
#         -0.2569142 ,  0.21196135, -0.19785877,  0.34804965],
#        [-0.12797725,  0.74182289,  0.09629328,  1.0060241 ,  0.12314364,
#         -0.2484822 ,  0.05471819, -0.16000656,  0.11619394],
#        [-0.52747354,  0.51989676,  0.1303592 ,  0.12314364,  1.0060241 ,
#         -0.14864609,  0.61564899, -0.50486319,  0.90096644],
#        [ 0.29001277, -0.10794074, -0.2569142 , -0.2484822 , -0.14864609,
#          1.0060241 , -0.24114897,  0.31883023, -0.22296618],
#        [-0.89201752,  0.3182181 ,  0.21196135,  0.05471819,  0.61564899,
#         -0.24114897,  1.0060241 , -0.76545827,  0.60370413],
# ...

# %%
eig_values,eig_vector=np.linalg.eig(cov_matraix)
eig_values
# Out:
# array([4.16057017, 1.55566165, 1.1774338 , 1.00077724, 0.66459866,
#        0.224928  , 0.06727787, 0.08884738, 0.1141221 ])

# %%
# Make a list of (eigenvalue, eigenvector) tuples
eig_pairs = [(np.abs(eig_values[i]), eig_vector[:,i]) for i in range(len(eig_values))]

# Sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs.sort(key=lambda x: x[0], reverse=True)

# Visually confirm that the list is correctly sorted by decreasing eigenvalues
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 4.160570174608565
# 1.555661647854347
# 1.1774338025373792
# 1.000777240588831
# 0.6645986608738874
# 0.22492799510065697
# 0.11412210171337517
# 0.08884737663271132
# 0.06727786756013206

# %%
tot=sum(eig_values)
var_exp = [(i / tot)*100 for i in sorted(eig_values, reverse=True)]
var_exp
# Out:
# [45.95173978609589,
#  17.18162565161819,
#  13.00425889695308,
#  11.053161805571913,
#  7.340211424156036,
#  2.4842346764277465,
#  1.260430398165021,
#  0.9812817379261523,
#  0.7430556230859556]

# %%
matrix_w = np.hstack((eig_pairs[0][1].reshape(9,1), 
                      eig_pairs[1][1].reshape(9,1)
                    ))
print('Matrix W:\n', matrix_w)
# Out:
# Matrix W:
#  [[ 0.41951945 -0.19288394]
#  [-0.28389698 -0.61316349]
#  [-0.15083782  0.24308678]
#  [-0.16148244 -0.67182064]
#  [-0.39844111 -0.02253553]
#  [ 0.19317293  0.00840447]
#  [-0.42583938  0.22270674]
#  [ 0.40372896 -0.15523311]
#  [-0.39264482  0.0460224 ]]

# %%
y=x_std.dot(matrix_w)
y
# Out:
# array([[ 2.91302459e+00, -9.56205755e-02],
#        [-4.29911330e-01,  5.88155666e-01],
#        [ 2.85225077e-01,  4.55174413e-01],
#        [ 2.93242265e+00, -1.69555507e+00],
#        [-1.03357587e+00, -1.36658709e-01],
#        [-2.24072616e-02,  1.77918658e+00],
#        [ 1.01583737e-01,  5.68251724e-01],
#        [-2.34216461e+00,  1.98845915e+00],
#        [-2.97376366e+00,  7.34688659e-01],
#        [ 1.81486997e-01,  4.02865873e-01],
#        [-1.26874386e+00,  6.56588363e-01],
#        [-1.67099640e+00, -5.61162493e-01],
#        [ 1.12385093e+00,  9.61397405e-01],
#        [-1.08137420e+00,  4.81969530e-01],
#        [-5.80025152e-01, -5.35326834e-01],
#        [-3.14378596e+00, -6.63547921e-01],
#        [-2.11255447e-01, -6.99242662e-01],
#        [ 2.67231388e+00, -4.18172125e-01],
#        [ 1.56570962e-01, -7.77395617e-01],
#        [ 7.93851561e-01,  1.20261085e-01],
#        [-9.95867143e-01,  9.71888439e-01],
#        [ 8.82087639e-01, -4.57368180e-01],
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
y=pca.fit_transform(x_std)
y
# Out:
# array([[-2.91302459e+00,  9.56205755e-02],
#        [ 4.29911330e-01, -5.88155666e-01],
#        [-2.85225077e-01, -4.55174413e-01],
#        [-2.93242265e+00,  1.69555507e+00],
#        [ 1.03357587e+00,  1.36658709e-01],
#        [ 2.24072616e-02, -1.77918658e+00],
#        [-1.01583737e-01, -5.68251724e-01],
#        [ 2.34216461e+00, -1.98845915e+00],
#        [ 2.97376366e+00, -7.34688659e-01],
#        [-1.81486997e-01, -4.02865873e-01],
#        [ 1.26874386e+00, -6.56588363e-01],
#        [ 1.67099640e+00,  5.61162493e-01],
#        [-1.12385093e+00, -9.61397405e-01],
#        [ 1.08137420e+00, -4.81969530e-01],
#        [ 5.80025152e-01,  5.35326834e-01],
#        [ 3.14378596e+00,  6.63547921e-01],
#        [ 2.11255447e-01,  6.99242662e-01],
#        [-2.67231388e+00,  4.18172125e-01],
#        [-1.56570962e-01,  7.77395617e-01],
#        [-7.93851561e-01, -1.20261085e-01],
#        [ 9.95867143e-01, -9.71888439e-01],
#        [-8.82087639e-01,  4.57368180e-01],
# ...

# %%
print(y)
# Out:
# PCA(n_components=2)

# %%
y
# Out:
# array([[-2.91302459e+00,  9.56205755e-02],
#        [ 4.29911330e-01, -5.88155666e-01],
#        [-2.85225077e-01, -4.55174413e-01],
#        [-2.93242265e+00,  1.69555507e+00],
#        [ 1.03357587e+00,  1.36658709e-01],
#        [ 2.24072616e-02, -1.77918658e+00],
#        [-1.01583737e-01, -5.68251724e-01],
#        [ 2.34216461e+00, -1.98845915e+00],
#        [ 2.97376366e+00, -7.34688659e-01],
#        [-1.81486997e-01, -4.02865873e-01],
#        [ 1.26874386e+00, -6.56588363e-01],
#        [ 1.67099640e+00,  5.61162493e-01],
#        [-1.12385093e+00, -9.61397405e-01],
#        [ 1.08137420e+00, -4.81969530e-01],
#        [ 5.80025152e-01,  5.35326834e-01],
#        [ 3.14378596e+00,  6.63547921e-01],
#        [ 2.11255447e-01,  6.99242662e-01],
#        [-2.67231388e+00,  4.18172125e-01],
#        [-1.56570962e-01,  7.77395617e-01],
#        [-7.93851561e-01, -1.20261085e-01],
#        [ 9.95867143e-01, -9.71888439e-01],
#        [-8.82087639e-01,  4.57368180e-01],
# ...

# %%
pd.DataFrame(y)
# Out:
#             0         1
# 0   -2.913025  0.095621
# 1    0.429911 -0.588156
# 2   -0.285225 -0.455174
# 3   -2.932423  1.695555
# 4    1.033576  0.136659
# ..        ...       ...
# 162 -0.820631  0.639570
# 163 -0.551036 -1.233886
# 164  0.498524  1.390744
# 165 -1.887451 -0.109453
# 166 -2.864064  0.485998
#
# [167 rows x 2 columns]
